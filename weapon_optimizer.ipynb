# %%
import numpy as np
import matplotlib.pyplot as plt
from typing import Tuple, Literal
from scipy.optimize import minimize_scalar
from multiprocessing import Pool
from functools import partial

# %% [markdown]
# # System Description:
#
# This is a simple spring loaded lever arm with a point mass at the far end representing the weapon. The distance between the base of the arm and the point mass is $r_w$, and the mass of the point mass is $m$. The distance between the base of the arm and the mounting point of the spring is $r_s$ and the spring constant is $k$. The other end of the spring is fixed relative to the base of the arm and is mounted at position $(x_s, y_s)$, letting the base of the arm be the origin.
#
# The arm is free to rotate about the base, causing the spring to be stretched or compressed. The length of the spring in its uncompressed state is $l_0$. The length of the spring at any given angle $\theta$ is given in Equation 1.
#
# \begin{equation}
#     \tag{1}
#     l(\theta) = \sqrt{(r_s \cos(\theta) - x_s)^2 + (r_s \sin(\theta) - y_s)^2}
# \end{equation}
#
# From Equation 1, it is possible to find the elastic potential energy stored in the spring at any given angle $\theta$. This is shown in Equation 2.
#
# \begin{equation}
#     \tag{2}
#     U_s(\theta) = \frac{1}{2} k (l(\theta) - l_0)^2
# \end{equation}
#
# The gravitional potential energy of the point mass is given in Equation 3.
#
# \begin{equation}
#     \tag{3}
#     U_g(\theta) = m g r_w \sin(\theta)
# \end{equation}
#
# Since both the gravitaional force and the spring force are conservitive, it is possible to find the approximate torque exerted on the arm at any given angle $\theta$ by taking the derivative of the total potential energy with respect to $\theta$. This is shown in Equation 4. Note that this is only an approximation, since there will also be a small torque due to changes in the angular velocity of the arm. However, this term will be so small as to be negligible.
#
# \begin{equation}
#     \tag{4}
#     \tau(\theta) = -\frac{d}{d\theta} (U_s(\theta) + U_g(\theta))
# \end{equation}
#
# Substututing the in Equations 2 and 3 into Equation 4 and simplifying gives Equation 5.
#
# \begin{equation}
#     \tag{5}
#     \tau(\theta) = - \left( kr_s \left( x_s \sin(\theta) - y_s \cos(\theta) \right) \frac{l(\theta) - l_0}{l(\theta)} + mgr_w \cos(\theta) \right)
# \end{equation}
#
# Ideally we would like the arm to impact the openent at a the angle $\theta_{impact}$ and be released from $\theta_{release}$, where $\tau(\theta_{impact}) = 0$ and $\tau(\theta_{release}) = 0$. These angles correspond to the points along the rotation of the arm at which the potential energy of the system is at its minimum and maximum energy, respectively. In this way the impact velocity of the weapon will be maximized, causing the greatest damage to the opponent. The linear velocity at $\theta_{impact}$ when released from $\theta_{release}$ is given in Equation 6.
#
# \begin{equation}
#     \tag{6}
#     v_{impact} = \sqrt{\frac{2 \left(U_s(\theta_{release}) - U_s(\theta_{impact}) + U_g(\theta_{release}) - U_g(\theta_{impact}) \right)}{m}}
# \end{equation}

# %%
class Springlock:
    # Helper variables to convert units
    _length_unit_conversins = {
        'm': 1.000,
        'cm': 1.000e-2,
        'mm': 1.000e-3,
        'ft': 0.3048,
        'in': 0.0254
    }

    _mass_unit_conversions = {
        'kg': 1.000,
        'g': 1.000e-3,
        'lb': 0.4536,
        'oz': 0.02835
    }

    _spring_constant_unit_conversions = {
        'N/m': 1.000,
        'lbf/in': 175.1
    }

    _speed_unit_conversions = {
        'm/s': 1.000,
        'ft/s': 0.3048,
        'mph': 0.4470
    }

    _torque_unit_conversions = {
        'N*m': 1.000,
        'lbf*ft': 1.356,
        'ozf*ft': 0.08474,
        'lbf*in': 0.1130,
        'ozf*in': 0.007062
    }

    _angle_unit_conversions = {
        'rad': 1.000,
        'deg': 0.01745
    }


    def __init__(self, weapon_radius: np.float64, weapon_mass: np.float64, spring_radius: np.float64, spring_constant: np.float64, spring_resting_length: np.float64, spring_mounting_point: Tuple[np.float64, np.float64],
                 *, length_units: Literal['m', 'cm', 'mm', 'ft', 'in'] = 'm', mass_units: Literal['kg', 'g', 'lb', 'oz'] = 'kg', spring_constant_units: Literal['N/m', 'lbf/in'] = 'N/m',
                    speed_units: Literal['m/s', 'ft/s', 'mph'] = 'm/s', torque_units: Literal['N*m', 'lbf*ft', 'ozf*ft', 'lbf*in', 'ozf*in'] = 'N*m', angle_units: Literal['rad', 'deg'] = 'rad'):
        
        """Creates a new Springlock object with the specified parameters.

        Args:
            weapon_radius (np.float64): The distance from the base of the arm to the center of the weapon.
            weapon_mass (np.float64): The mass of the weapon.
            spring_radius (np.float64): The distance from the base of the arm to the mounting point of the spring.
            spring_constant (np.float64): The spring constant of the springs. If multiple springs are used in parallel, this should be the sum of the sprting constants.
            spring_resting_length (np.float64): The length of the spring when it is not under any tension or compression.
            spring_mounting_point (Tuple[np.float64, np.float64]): The x and y coordinates of the fixed mounting point of the spring, relative to the base of the arm
        """
        

        self._length_scale = Springlock._length_unit_conversins[length_units]
        self._mass_scale = Springlock._mass_unit_conversions[mass_units]
        self._spring_constant_scale = Springlock._spring_constant_unit_conversions[spring_constant_units]
        self._speed_scale = Springlock._speed_unit_conversions[speed_units]
        self._torque_scale = Springlock._torque_unit_conversions[torque_units]
        self._angle_scale = Springlock._angle_unit_conversions[angle_units]

        # Class variables that will not be changed
        self._weapon_radius = weapon_radius * self._length_scale
        self._weapon_mass = weapon_mass * self._mass_scale
        self._spring_radius = spring_radius * self._length_scale
        self._spring_constant = spring_constant * self._spring_constant_scale
        self._spring_resting_length = spring_resting_length * self._length_scale
        self._spring_mounting_point = (spring_mounting_point[0] * self._length_scale, spring_mounting_point[1] * self._length_scale)

        self._length_units = length_units
        self._mass_units = mass_units
        self._spring_constant_units = spring_constant_units
        self._speed_units = speed_units
        self._torque_units = torque_units
        self._angle_units = angle_units

        # Class variables that will be calculated and memoized as needed
        self._max_theta = None
        self._min_theta = None
        self._max_torque_theta = None


    ############################
    ###### Getter Methods ######
    ############################
    @property
    def weapon_radius(self) -> np.float64:
        return self._weapon_radius / self._length_scale
    
    @property
    def weapon_mass(self) -> np.float64:
        return self._weapon_mass / self._mass_scale
    
    @property
    def spring_radius(self) -> np.float64:
        return self._spring_radius / self._length_scale
    
    @property
    def spring_constant(self) -> np.float64:
        return self._spring_constant / self._spring_constant_scale
    
    @property
    def spring_resting_length(self) -> np.float64:
        return self._spring_resting_length / self._length_scale
    
    @property
    def spring_mounting_point(self) -> Tuple[np.float64, np.float64]:
        return (self._spring_mounting_point[0] / self._length_scale, self._spring_mounting_point[1] / self._length_scale)
    
    @property
    def spring_mounting_point_x(self) -> np.float64:
        return self._spring_mounting_point[0] / self._length_scale
    
    @property
    def spring_mounting_point_y(self) -> np.float64:
        return self._spring_mounting_point[1] / self._length_scale
    
    @property
    def tip_to_spring(self) -> np.float64:
        return self.weapon_radius - self.spring_radius
    
    @property
    def max_theta(self) -> np.float64:
        if self._max_theta is None:
            self._max_theta = self._calculate_max_theta()
        return self._max_theta / self._angle_scale
    
    @property
    def release_angle(self) -> np.float64:
        return self.max_theta
    
    @property
    def max_potential_energy(self) -> np.float64:
        if self._max_theta is None:
            self._max_theta = self._calculate_max_theta()
        return self._total_potential_energy(self._max_theta)
    
    @property
    def min_theta(self) -> np.float64:
        if self._min_theta is None:
            self._min_theta = self._calculate_min_theta()
        return self._min_theta / self._angle_scale
    
    @property
    def impact_angle(self) -> np.float64:
        return self.min_theta
    
    @property
    def min_potential_energy(self) -> np.float64:
        if self._min_theta is None:
            self._min_theta = self._calculate_min_theta()
        return self._total_potential_energy(self._min_theta)
    
    @property
    def max_speed(self) -> np.float64:
        return (np.sqrt(2 * (self.max_potential_energy - self.min_potential_energy) / self._weapon_mass)) / self._speed_scale
    
    @property
    def max_torque_theta(self) -> np.float64:
        if self._max_torque_theta is None:
            self._max_torque_theta = self._calculate_max_torque_theta()
        return self._max_torque_theta / self._angle_scale
    
    @property
    def max_torque(self) -> np.float64:
        if self._max_torque_theta is None:
            self._max_torque_theta = self._calculate_max_torque_theta()
        return np.abs(self._torque(self._max_torque_theta)) / self._torque_scale
    

    ###################################
    ###### Unit conversion stuff ######
    ###################################

    @property
    def length_units(self) -> Literal['m', 'cm', 'mm', 'ft', 'in']:
        return self._length_units
    
    @length_units.setter
    def length_units(self, value: Literal['m', 'cm', 'mm', 'ft', 'in']):
        self._length_units = value
        self._length_scale = Springlock._length_unit_conversions[value]

    @property
    def mass_units(self) -> Literal['kg', 'g', 'lb', 'oz']:
        return self._mass_units
    
    @mass_units.setter
    def mass_units(self, value: Literal['kg', 'g', 'lb', 'oz']):
        self._mass_units = value
        self._mass_scale = Springlock._mass_unit_conversions[value]

    @property
    def spring_constant_units(self) -> Literal['N/m', 'lbf/in']:
        return self._spring_constant_units
    
    @spring_constant_units.setter
    def spring_constant_units(self, value: Literal['N/m', 'lbf/in']):
        self._spring_constant_units = value
        self._spring_constant_scale = Springlock._spring_constant_unit_conversions[value]

    @property
    def speed_units(self) -> Literal['m/s', 'ft/s', 'mph']:
        return self._speed_units
    
    @speed_units.setter
    def speed_units(self, value: Literal['m/s', 'ft/s', 'mph']):
        self._speed_units = value
        self._speed_scale = Springlock._speed_unit_conversions[value]

    @property
    def torque_units(self) -> Literal['N*m', 'lbf*ft', 'ozf*ft', 'lbf*in', 'ozf*in']:
        return self._torque_units
    
    @torque_units.setter
    def torque_units(self, value: Literal['N*m', 'lbf*ft', 'ozf*ft', 'lbf*in', 'ozf*in']):
        self._torque_units = value
        self._torque_scale = Springlock._torque_unit_conversions[value]

    @property
    def angle_units(self) -> Literal['rad', 'deg']:
        return self._angle_units
    
    @angle_units.setter
    def angle_units(self, value: Literal['rad', 'deg']):
        self._angle_units = value
        self._angle_scale = Springlock._angle_unit_conversions[value]

    @property
    def energy_units(self) -> Literal['J']:
        return 'J'
    

    #############################
    ###### Physics Methods ######
    #############################

    def spring_length(self, arm_angle: np.float64) -> np.float64:
        """Calculates the length of the spring at a given arm angle.

        Args:
            arm_angle (np.float64): The angle of the arm in radians.

        Returns:
            np.float64: The length of the spring.
        """
        return self._spring_length(arm_angle * self._angle_scale) / self._length_scale

    def _spring_length(self, arm_angle: np.float64) -> np.float64:
        """Calculates the length of the spring at a given arm angle.

        Args:
            arm_angle (np.float64): The angle of the arm in radians.

        Returns:
            np.float64: The length of the spring.
        """
        return np.sqrt((self._spring_mounting_point[0] - self._spring_radius * np.cos(arm_angle))**2 + (self._spring_mounting_point[1] + self._spring_radius * np.sin(arm_angle))**2)
    
    def spring_potential_energy(self, arm_angle: np.float64) -> np.float64:
        """Calculates the energy stored in the spring at a given arm angle.

        Args:
            arm_angle (np.float64): The angle of the arm in radians.

        Returns:
            np.float64: The energy stored in the spring.
        """
        return self._spring_potential_energy(arm_angle * self._angle_scale)
    
    def _spring_potential_energy(self, arm_angle: np.float64) -> np.float64:
        return 0.5 * self._spring_constant * (self._spring_length(arm_angle) - self._spring_resting_length)**2
    
    def gravitational_potential_energy(self, arm_angle: np.float64) -> np.float64:
        """Calculates the gravitational potential energy of the weapon at a given arm angle.

        Args:
            arm_angle (np.float64): The angle of the arm in radians.

        Returns:
            np.float64: The gravitational potential energy of the weapon.
        """
        return self._gravitational_potential_energy(arm_angle * self._angle_scale)
    
    def _gravitational_potential_energy(self, arm_angle: np.float64) -> np.float64:
        return self._weapon_mass * 9.81 * self._weapon_radius * np.sin(arm_angle)
    
    def total_potential_energy(self, arm_angle: np.float64) -> np.float64:
        """Calculates the total potential energy of the system at a given arm angle.

        Args:
            arm_angle (np.float64): The angle of the arm in radians.

        Returns:
            np.float64: The total potential energy of the system.
        """
        return self._total_potential_energy(arm_angle * self._angle_scale)
    
    def _total_potential_energy(self, arm_angle: np.float64) -> np.float64:
        return self._spring_potential_energy(arm_angle) + self._gravitational_potential_energy(arm_angle)
    
    def torque(self, arm_angle: np.float64) -> np.float64:
        """Calculates the torque on the arm at a given arm angle.

        Args:
            arm_angle (np.float64): The angle of the arm in radians.

        Returns:
            np.float64: The torque on the arm.
        """
        return self._torque(arm_angle * self._angle_scale) / self._torque_scale
    
    def _torque(self, arm_angle: np.float64) -> np.float64:
        spring_torque = self._spring_constant * self._spring_radius * (self._spring_mounting_point[0] * np.sin(arm_angle) - self._spring_mounting_point[1] * np.cos(arm_angle)) * (self._spring_length(arm_angle) - self._spring_resting_length) / self._spring_length(arm_angle)
        gravity_torque = self._weapon_mass * 9.81 * self._weapon_radius * np.cos(arm_angle)
        return -(spring_torque + gravity_torque)
    

    ############################
    ###### Helper Methods ######
    ############################

    def _calculate_max_theta(self) -> np.float64:
        """Calculates the angle of the arm at which the total potential energy of the system is maximized.

        Returns:
            np.float64: The maximum angle of the arm in radians.
        """
        optimize_results = minimize_scalar(lambda x: -self._total_potential_energy(x), bounds=(-np.pi, np.pi), method='bounded')

        if optimize_results.success:
            return optimize_results.x
        else:
            raise RuntimeError('Unable to find maximum potential energy of springlock system')
    
    def _calculate_min_theta(self) -> np.float64:
        """Calculates the angle of the arm at which the total potential energy of the system is minimized.

        Returns:
            np.float64: The minimum angle of the arm in radians.
        """
        optimize_results = minimize_scalar(lambda x: self._total_potential_energy(x), bounds=(-np.pi, np.pi), method='bounded')

        if optimize_results.success:
            return optimize_results.x
        else:
            raise RuntimeError('Unable to find minimum potential energy of springlock system')
        
    def _calculate_max_torque_theta(self) -> np.float64:
        """Calculates the maximum torque on the arm.

        Returns:
            np.float64: The maximum torque on the arm.
        """
        optimize_results = minimize_scalar(lambda x: -(self._torque(x) ** 2), bounds=(self._min_theta, self._max_theta), method='bounded')

        if optimize_results.success:
            return optimize_results.x
        else:
            raise RuntimeError('Unable to find maximum torque of springlock system')

# %% [markdown]
# # Optimization parameters
#
# The following options are available for optimization:
#
# - `min_weapon_mass`: The minimum mass of the weapon in pounds
# - `max_weapon_mass`: The maximum mass of the weapon in pounds
# - `min_weapon_radius`: The minimum length of the arm in inches
# - `max_weapon_radius`: The maximum length of the arm in inches
# - `min_spring_constant`: The minimum spring constant in pounds per inch
# - `max_spring_constant`: The maximum spring constant in pounds per inch
# - `min_spring_radius`: The minimum distance between the base of the arm and the spring
# - `max_spring_radius`: The maximum distance between the base of the arm and the spring
# - `min_tip_to_spring`: The minnumum distance that can be between the end of the arm and the spring mount point in inches
# - `min_spring_resting_length`: The minimum resting length of the spring in inches
# - `max_spring_resting_length`: The maximum resting length of the spring in inches
# - `min_spring_mounting_point_x`: The minimum x coordinate of the spring mount wrt the base of the arm in inches
# - `max_spring_mounting_point_x`: The maximum x coordinate of the spring mount wrt the base of the arm in inches
# - `min_spring_mounting_point_y`: The minimum y coordinate of the spring mount wrt the base of the arm in inches
# - `max_spring_mounting_point_y`: The maximum y coordinate of the spring mount wrt the base of the arm in inches
# - `min_impact_angle`: The minimum angle at which the weapon can impact the opponent in degrees
# - `max_impact_angle`: The maximum angle at which the weapon can impact the opponent in degrees
# - `min_release_angle`: The minimum angle at which the weapon can be released in degrees
# - `max_release_angle`: The maximum angle at which the weapon can be released in degrees
#
#
# # Optimization objective
#
#
# - `target_speed`: The target speed of the weapon at impact in mph. The optimization will attempt to find a set of system parameters that will result in the smallest maximum torque while still achieving the target speed.

# %%
# Minimum and maximum system parameters
min_weapon_mass = 3 # kg
max_weapon_mass = 5 # kg
min_weapon_radius = 0.2 # m
max_weapon_radius = 0.4 # m
min_spring_constant = 1 # N/m
max_spring_constant = 1e6 # N/m
min_spring_radius = 0.01 # m
max_spring_radius = 0.6 # m
min_tip_to_spring = 0.15 # m
min_spring_resting_length = 0.01 # m
max_spring_resting_length = 0.6 # m
min_spring_mounting_point_x = -0.15 # m
max_spring_mounting_point_x = 0.15 # m
min_spring_mounting_point_y = -0.10 # m
max_spring_mounting_point_y = 0.10 # m
min_impact_angle = -15 # degrees
max_impact_angle = 15 # degrees
min_release_angle = 60 # degrees
max_release_angle = 120 # degrees

target_speed = 10 # m/s

# %% [markdown]
# # EA Code

# %%
# EA parameters
population_size = 1000
max_generations = 1000
mutation_rate = 0.9
mutation_scale = 0.25
termination_precision = 1e-6
genome_size = 7
viable_population_ratio = 0.5 # The top 50% of the population will be selected for reproduction
fitness_exponent = 1.01 # Each specimen will have 1/n the chance of the next most fit specimen of being selected for reproduction

genome_mapping = [
    'weapon_mass',
    'weapon_radius',
    'spring_constant',
    'spring_radius',
    'spring_resting_length',
    'spring_mounting_point'
]

genome_ranges = [
    (min_weapon_mass, max_weapon_mass),
    (min_weapon_radius, max_weapon_radius),
    (min_spring_constant, max_spring_constant),
    (min_spring_radius, max_spring_radius),
    (min_spring_resting_length, max_spring_resting_length),
    (min_spring_mounting_point_x, max_spring_mounting_point_x),
    (min_spring_mounting_point_y, max_spring_mounting_point_y)
]

# %%
def fitness(genome):
    genome = [*genome[:-2], (genome[-2], genome[-1])]
    genome_dict = dict(zip(genome_mapping, genome))
    springlock = Springlock(**genome_dict, angle_units='deg')

    # If all the values are within the bounds, the fitness is one over the torque
    # Otherwise, the fitness is the negative sum of how bad all the violations are
    fitness = None

    if springlock.weapon_mass < min_weapon_mass or springlock.weapon_mass > max_weapon_mass:
        if fitness is None:
            fitness = 0
        fitness -= np.abs(springlock.weapon_mass - (min_weapon_mass + max_weapon_mass) / 2) / ((max_weapon_mass - min_weapon_mass) / 2)

    if springlock.weapon_radius < min_weapon_radius or springlock.weapon_radius > max_weapon_radius:
        if fitness is None:
            fitness = 0
        fitness -= np.abs(springlock.weapon_radius - (min_weapon_radius + max_weapon_radius) / 2) / ((max_weapon_radius - min_weapon_radius) / 2)

    if springlock.spring_constant < min_spring_constant or springlock.spring_constant > max_spring_constant:
        if fitness is None:
            fitness = 0
        fitness -= np.abs(springlock.spring_constant - (min_spring_constant + max_spring_constant) / 2) / ((max_spring_constant - min_spring_constant) / 2)

    if springlock.spring_radius < min_spring_radius or springlock.spring_radius > max_spring_radius:
        if fitness is None:
            fitness = 0
        fitness -= np.abs(springlock.spring_radius - (min_spring_radius + max_spring_radius) / 2) / ((max_spring_radius - min_spring_radius) / 2)

    if springlock.tip_to_spring < min_tip_to_spring:
        if fitness is None:
            fitness = 0
        fitness -= np.abs(springlock.tip_to_spring - min_tip_to_spring) / min_tip_to_spring

    if springlock.spring_resting_length < min_spring_resting_length or springlock.spring_resting_length > max_spring_resting_length:
        if fitness is None:
            fitness = 0
        fitness -= np.abs(springlock.spring_resting_length - (min_spring_resting_length + max_spring_resting_length) / 2) / ((max_spring_resting_length - min_spring_resting_length) / 2)

    if springlock.spring_mounting_point[0] < min_spring_mounting_point_x or springlock.spring_mounting_point[0] > max_spring_mounting_point_x:
        if fitness is None:
            fitness = 0
        fitness -= np.abs(springlock.spring_mounting_point[0] - (min_spring_mounting_point_x + max_spring_mounting_point_x) / 2) / ((max_spring_mounting_point_x - min_spring_mounting_point_x) / 2)

    if springlock.spring_mounting_point[1] < min_spring_mounting_point_y or springlock.spring_mounting_point[1] > max_spring_mounting_point_y:
        if fitness is None:
            fitness = 0
        fitness -= np.abs(springlock.spring_mounting_point[1] - (min_spring_mounting_point_y + max_spring_mounting_point_y) / 2) / ((max_spring_mounting_point_y - min_spring_mounting_point_y) / 2)

    if springlock.impact_angle < min_impact_angle or springlock.impact_angle > max_impact_angle:
        if fitness is None:
            fitness = 0
        fitness -= np.abs(springlock.impact_angle - (min_impact_angle + max_impact_angle) / 2) / ((max_impact_angle - min_impact_angle) / 2)

    if springlock.release_angle < min_release_angle or springlock.release_angle > max_release_angle:
        if fitness is None:
            fitness = 0
        fitness -= np.abs(springlock.release_angle - (min_release_angle + max_release_angle) / 2) / ((max_release_angle - min_release_angle) / 2)

    if springlock.max_speed < target_speed:
        if fitness is None:
            fitness = 0
        fitness -= 100 * np.abs(springlock.max_speed - target_speed) / target_speed

    if fitness is None:
        fitness = 1 / abs(springlock.max_torque)

    return fitness


def evaluate_population(population):
    with Pool() as pool:
        fitnesses = pool.map(fitness, population)        
    population, fitnesses = zip(*sorted(zip(population, fitnesses), key=lambda x: x[1], reverse=True))
    return list(population), list(fitnesses)


def parent_selection(population):
    population, _ = evaluate_population(population)
    return population[:int(len(population) * viable_population_ratio)]

def create_child(parents):
    max_rand = (1 / fitness_exponent) ** (len(parents) - 1)
    parent_1_idx = int(np.log(np.random.uniform(low=0, high=max_rand)) / np.log(1 / fitness_exponent))
    parent_2_idx = int(np.log(np.random.uniform(low=0, high=max_rand)) / np.log(1 / fitness_exponent))

    parent_1 = parents[min(len(parents) - 1, parent_1_idx)]
    parent_2 = parents[min(len(parents) - 1, parent_2_idx)]

    child = []

    for i in range(len(parent_1)):
        if np.random.rand() < 0.5:
            child.append(parent_1[i])
        else:
            child.append(parent_2[i])

    for i in range(len(child)):
        if np.random.rand() < mutation_rate:
            mutation_magnitude = (np.random.rand() * 2 * mutation_scale - mutation_scale) * child[i]
            child[i] += mutation_magnitude

            child[i] = max(child[i], genome_ranges[i][0])
            child[i] = min(child[i], genome_ranges[i][1])

    return child


def crossover(parents):
    # return [create_child(parents) for _ in range(population_size)]
    with Pool() as pool:
        # create a partial function that has the parents argument already filled in
        children = pool.map(create_child, [parents] * population_size)

    return children


def survivor_selection(population, children):
    population, fitnesses = evaluate_population(population + children)
    return population[:population_size], fitnesses[:population_size]

# %%
# Initialize the population
population = [
    [np.random.uniform(high=genome_ranges[i][1], low=genome_ranges[i][0]) for i in range(genome_size)]
    for _ in range(population_size)
]

# Run the genetic algorithm
for generation in range(1, max_generations + 1):
    parents = parent_selection(population)
    children = crossover(parents)
    population, fitnesses = survivor_selection(parents, children)

    best_fitness = max(fitnesses)
    average_fitness = sum(fitnesses) / len(fitnesses)

    print(f"Generation {generation:4d} | Best fitness: {best_fitness:10.4f} | Average fitness: {average_fitness:10.4f}")
# Out:
# Generation    1 | Best fitness:    -1.2372 | Average fitness:    -5.4218
# Generation    2 | Best fitness:     0.0022 | Average fitness:    -3.2564
# Generation    3 | Best fitness:     0.0044 | Average fitness:    -1.3744
# Generation    4 | Best fitness:     0.0080 | Average fitness:    -0.7784
# Generation    5 | Best fitness:     0.0107 | Average fitness:    -0.7166
# Generation    6 | Best fitness:     0.0140 | Average fitness:    -0.7287
# Generation    7 | Best fitness:     0.0140 | Average fitness:    -0.6484
# Generation    8 | Best fitness:     0.0148 | Average fitness:    -0.4984
# Generation    9 | Best fitness:     0.0148 | Average fitness:    -1.0623
# Generation   10 | Best fitness:     0.0161 | Average fitness:    -1.1271
# Generation   11 | Best fitness:     0.0161 | Average fitness:    -1.0818
# Generation   12 | Best fitness:     0.0161 | Average fitness:    -1.2370
# Generation   13 | Best fitness:     0.0161 | Average fitness:    -1.2534
# Generation   14 | Best fitness:     0.0161 | Average fitness:    -1.2562
# Generation   15 | Best fitness:     0.0161 | Average fitness:    -1.2562
# Generation   16 | Best fitness:     0.0161 | Average fitness:    -1.2692
# Generation   17 | Best fitness:     0.0161 | Average fitness:    -1.2561
# Generation   18 | Best fitness:     0.0161 | Average fitness:    -1.2561
# Generation   19 | Best fitness:     0.0161 | Average fitness:    -1.2523
# Generation   20 | Best fitness:     0.0161 | Average fitness:    -1.2560
# Generation   21 | Best fitness:     0.0161 | Average fitness:    -1.2556
# Generation   22 | Best fitness:     0.0161 | Average fitness:    -1.2481
# Generation   23 | Best fitness:     0.0161 | Average fitness:    -1.2629
# Generation   24 | Best fitness:     0.0161 | Average fitness:    -1.2486
# Generation   25 | Best fitness:     0.0161 | Average fitness:    -1.2560
# Generation   26 | Best fitness:     0.0161 | Average fitness:    -1.2560
# Generation   27 | Best fitness:     0.0161 | Average fitness:    -1.2629
# Generation   28 | Best fitness:     0.0161 | Average fitness:    -1.2703
# Generation   29 | Best fitness:     0.0161 | Average fitness:    -1.2387
# Generation   30 | Best fitness:     0.0161 | Average fitness:    -1.2629
# Generation   31 | Best fitness:     0.0161 | Average fitness:    -1.2462
# Generation   32 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation   33 | Best fitness:     0.0161 | Average fitness:    -1.2457
# Generation   34 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation   35 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation   36 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation   37 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation   38 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation   39 | Best fitness:     0.0161 | Average fitness:    -1.2387
# Generation   40 | Best fitness:     0.0161 | Average fitness:    -1.2769
# Generation   41 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation   42 | Best fitness:     0.0161 | Average fitness:    -1.2312
# Generation   43 | Best fitness:     0.0161 | Average fitness:    -1.2312
# Generation   44 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation   45 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation   46 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation   47 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation   48 | Best fitness:     0.0161 | Average fitness:    -1.2690
# Generation   49 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation   50 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation   51 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation   52 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation   53 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation   54 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation   55 | Best fitness:     0.0161 | Average fitness:    -1.2690
# Generation   56 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation   57 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation   58 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation   59 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation   60 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation   61 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation   62 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation   63 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation   64 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation   65 | Best fitness:     0.0161 | Average fitness:    -1.2411
# Generation   66 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation   67 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation   68 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation   69 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation   70 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation   71 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation   72 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation   73 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation   74 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation   75 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation   76 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation   77 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation   78 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation   79 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation   80 | Best fitness:     0.0161 | Average fitness:    -1.2406
# Generation   81 | Best fitness:     0.0161 | Average fitness:    -1.2308
# Generation   82 | Best fitness:     0.0161 | Average fitness:    -1.2517
# Generation   83 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation   84 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation   85 | Best fitness:     0.0161 | Average fitness:    -1.2738
# Generation   86 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation   87 | Best fitness:     0.0161 | Average fitness:    -1.2387
# Generation   88 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation   89 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation   90 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation   91 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation   92 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation   93 | Best fitness:     0.0161 | Average fitness:    -1.2621
# Generation   94 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation   95 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation   96 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation   97 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation   98 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation   99 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  100 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  101 | Best fitness:     0.0161 | Average fitness:    -1.2307
# Generation  102 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  103 | Best fitness:     0.0161 | Average fitness:    -1.2690
# Generation  104 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  105 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  106 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  107 | Best fitness:     0.0161 | Average fitness:    -1.2211
# Generation  108 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  109 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  110 | Best fitness:     0.0161 | Average fitness:    -1.2382
# Generation  111 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  112 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  113 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  114 | Best fitness:     0.0161 | Average fitness:    -1.2411
# Generation  115 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  116 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  117 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  118 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  119 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  120 | Best fitness:     0.0161 | Average fitness:    -1.2621
# Generation  121 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  122 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  123 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  124 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  125 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  126 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  127 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  128 | Best fitness:     0.0161 | Average fitness:    -1.2388
# Generation  129 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  130 | Best fitness:     0.0161 | Average fitness:    -1.2457
# Generation  131 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  132 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  133 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  134 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  135 | Best fitness:     0.0161 | Average fitness:    -1.2382
# Generation  136 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  137 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  138 | Best fitness:     0.0161 | Average fitness:    -1.2414
# Generation  139 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  140 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  141 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  142 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  143 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  144 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  145 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  146 | Best fitness:     0.0161 | Average fitness:    -1.2443
# Generation  147 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  148 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  149 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  150 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  151 | Best fitness:     0.0161 | Average fitness:    -1.2480
# Generation  152 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  153 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  154 | Best fitness:     0.0161 | Average fitness:    -1.2621
# Generation  155 | Best fitness:     0.0161 | Average fitness:    -1.2373
# Generation  156 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  157 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  158 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  159 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  160 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  161 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  162 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  163 | Best fitness:     0.0161 | Average fitness:    -1.2621
# Generation  164 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  165 | Best fitness:     0.0161 | Average fitness:    -1.2387
# Generation  166 | Best fitness:     0.0161 | Average fitness:    -1.2387
# Generation  167 | Best fitness:     0.0161 | Average fitness:    -1.2312
# Generation  168 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  169 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  170 | Best fitness:     0.0161 | Average fitness:    -1.2690
# Generation  171 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  172 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  173 | Best fitness:     0.0161 | Average fitness:    -1.2411
# Generation  174 | Best fitness:     0.0161 | Average fitness:    -1.2411
# Generation  175 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  176 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  177 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  178 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  179 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  180 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  181 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  182 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  183 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  184 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  185 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  186 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  187 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  188 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  189 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  190 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  191 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  192 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  193 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  194 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  195 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  196 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  197 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  198 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  199 | Best fitness:     0.0161 | Average fitness:    -1.2473
# Generation  200 | Best fitness:     0.0161 | Average fitness:    -1.2517
# Generation  201 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  202 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  203 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  204 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  205 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  206 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  207 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  208 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  209 | Best fitness:     0.0161 | Average fitness:    -1.2447
# Generation  210 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  211 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  212 | Best fitness:     0.0161 | Average fitness:    -1.2678
# Generation  213 | Best fitness:     0.0161 | Average fitness:    -1.2417
# Generation  214 | Best fitness:     0.0161 | Average fitness:    -1.2457
# Generation  215 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  216 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  217 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  218 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  219 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  220 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  221 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  222 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  223 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  224 | Best fitness:     0.0161 | Average fitness:    -1.2764
# Generation  225 | Best fitness:     0.0161 | Average fitness:    -1.2764
# Generation  226 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  227 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  228 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  229 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  230 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  231 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  232 | Best fitness:     0.0161 | Average fitness:    -1.2621
# Generation  233 | Best fitness:     0.0161 | Average fitness:    -1.2480
# Generation  234 | Best fitness:     0.0161 | Average fitness:    -1.2542
# Generation  235 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  236 | Best fitness:     0.0161 | Average fitness:    -1.2695
# Generation  237 | Best fitness:     0.0161 | Average fitness:    -1.2411
# Generation  238 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  239 | Best fitness:     0.0161 | Average fitness:    -1.2480
# Generation  240 | Best fitness:     0.0161 | Average fitness:    -1.2616
# Generation  241 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  242 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  243 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  244 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  245 | Best fitness:     0.0161 | Average fitness:    -1.2354
# Generation  246 | Best fitness:     0.0161 | Average fitness:    -1.2813
# Generation  247 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  248 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  249 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  250 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  251 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  252 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  253 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  254 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  255 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  256 | Best fitness:     0.0161 | Average fitness:    -1.2387
# Generation  257 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  258 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  259 | Best fitness:     0.0161 | Average fitness:    -1.2621
# Generation  260 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  261 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  262 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  263 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  264 | Best fitness:     0.0161 | Average fitness:    -1.2480
# Generation  265 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  266 | Best fitness:     0.0161 | Average fitness:    -1.2769
# Generation  267 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  268 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  269 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  270 | Best fitness:     0.0161 | Average fitness:    -1.2447
# Generation  271 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  272 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  273 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  274 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  275 | Best fitness:     0.0161 | Average fitness:    -1.2621
# Generation  276 | Best fitness:     0.0161 | Average fitness:    -1.2462
# Generation  277 | Best fitness:     0.0161 | Average fitness:    -1.2480
# Generation  278 | Best fitness:     0.0161 | Average fitness:    -1.2522
# Generation  279 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  280 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  281 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  282 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  283 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  284 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  285 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  286 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  287 | Best fitness:     0.0161 | Average fitness:    -1.2387
# Generation  288 | Best fitness:     0.0161 | Average fitness:    -1.2752
# Generation  289 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  290 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  291 | Best fitness:     0.0161 | Average fitness:    -1.2480
# Generation  292 | Best fitness:     0.0161 | Average fitness:    -1.2542
# Generation  293 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  294 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  295 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  296 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  297 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  298 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  299 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  300 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  301 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  302 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  303 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  304 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  305 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  306 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  307 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  308 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  309 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  310 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  311 | Best fitness:     0.0161 | Average fitness:    -1.2764
# Generation  312 | Best fitness:     0.0161 | Average fitness:    -1.2462
# Generation  313 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  314 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  315 | Best fitness:     0.0161 | Average fitness:    -1.2542
# Generation  316 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  317 | Best fitness:     0.0161 | Average fitness:    -1.2406
# Generation  318 | Best fitness:     0.0161 | Average fitness:    -1.2411
# Generation  319 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  320 | Best fitness:     0.0161 | Average fitness:    -1.2567
# Generation  321 | Best fitness:     0.0161 | Average fitness:    -1.2448
# Generation  322 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  323 | Best fitness:     0.0161 | Average fitness:    -1.2664
# Generation  324 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  325 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  326 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  327 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  328 | Best fitness:     0.0161 | Average fitness:    -1.2447
# Generation  329 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  330 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  331 | Best fitness:     0.0161 | Average fitness:    -1.2276
# Generation  332 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  333 | Best fitness:     0.0161 | Average fitness:    -1.2616
# Generation  334 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  335 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  336 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  337 | Best fitness:     0.0161 | Average fitness:    -1.2457
# Generation  338 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  339 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  340 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  341 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  342 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  343 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  344 | Best fitness:     0.0161 | Average fitness:    -1.2411
# Generation  345 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  346 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  347 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  348 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  349 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  350 | Best fitness:     0.0161 | Average fitness:    -1.2387
# Generation  351 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  352 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  353 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  354 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  355 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  356 | Best fitness:     0.0161 | Average fitness:    -1.2664
# Generation  357 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  358 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  359 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  360 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  361 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  362 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  363 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  364 | Best fitness:     0.0161 | Average fitness:    -1.2369
# Generation  365 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  366 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  367 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  368 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  369 | Best fitness:     0.0161 | Average fitness:    -1.2690
# Generation  370 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  371 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  372 | Best fitness:     0.0161 | Average fitness:    -1.2337
# Generation  373 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  374 | Best fitness:     0.0161 | Average fitness:    -1.2312
# Generation  375 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  376 | Best fitness:     0.0161 | Average fitness:    -1.2411
# Generation  377 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  378 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  379 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  380 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  381 | Best fitness:     0.0161 | Average fitness:    -1.2664
# Generation  382 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  383 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  384 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  385 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  386 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  387 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  388 | Best fitness:     0.0161 | Average fitness:    -1.2312
# Generation  389 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  390 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  391 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  392 | Best fitness:     0.0161 | Average fitness:    -1.2312
# Generation  393 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  394 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  395 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  396 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  397 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  398 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  399 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  400 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  401 | Best fitness:     0.0161 | Average fitness:    -1.2695
# Generation  402 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  403 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  404 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  405 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  406 | Best fitness:     0.0161 | Average fitness:    -1.2387
# Generation  407 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  408 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  409 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  410 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  411 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  412 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  413 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  414 | Best fitness:     0.0161 | Average fitness:    -1.2738
# Generation  415 | Best fitness:     0.0161 | Average fitness:    -1.2457
# Generation  416 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  417 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  418 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  419 | Best fitness:     0.0161 | Average fitness:    -1.2769
# Generation  420 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  421 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  422 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  423 | Best fitness:     0.0161 | Average fitness:    -1.2411
# Generation  424 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  425 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  426 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  427 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  428 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  429 | Best fitness:     0.0161 | Average fitness:    -1.2462
# Generation  430 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  431 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  432 | Best fitness:     0.0161 | Average fitness:    -1.2664
# Generation  433 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  434 | Best fitness:     0.0161 | Average fitness:    -1.2462
# Generation  435 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  436 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  437 | Best fitness:     0.0161 | Average fitness:    -1.2547
# Generation  438 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  439 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  440 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  441 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  442 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  443 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  444 | Best fitness:     0.0161 | Average fitness:    -1.2382
# Generation  445 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  446 | Best fitness:     0.0161 | Average fitness:    -1.2462
# Generation  447 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  448 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  449 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  450 | Best fitness:     0.0161 | Average fitness:    -1.2406
# Generation  451 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  452 | Best fitness:     0.0161 | Average fitness:    -1.2616
# Generation  453 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  454 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  455 | Best fitness:     0.0161 | Average fitness:    -1.2621
# Generation  456 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  457 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  458 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  459 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  460 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  461 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  462 | Best fitness:     0.0161 | Average fitness:    -1.2480
# Generation  463 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  464 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  465 | Best fitness:     0.0161 | Average fitness:    -1.2664
# Generation  466 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  467 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  468 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  469 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  470 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  471 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  472 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  473 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  474 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  475 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  476 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  477 | Best fitness:     0.0161 | Average fitness:    -1.2563
# Generation  478 | Best fitness:     0.0161 | Average fitness:    -1.2343
# Generation  479 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  480 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  481 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  482 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  483 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  484 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  485 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  486 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  487 | Best fitness:     0.0161 | Average fitness:    -1.2480
# Generation  488 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  489 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  490 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  491 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  492 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  493 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  494 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  495 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  496 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  497 | Best fitness:     0.0161 | Average fitness:    -1.2590
# Generation  498 | Best fitness:     0.0161 | Average fitness:    -1.2695
# Generation  499 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  500 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  501 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  502 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  503 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  504 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  505 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  506 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  507 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  508 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  509 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  510 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  511 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  512 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  513 | Best fitness:     0.0161 | Average fitness:    -1.2411
# Generation  514 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  515 | Best fitness:     0.0161 | Average fitness:    -1.2411
# Generation  516 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  517 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  518 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  519 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  520 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  521 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  522 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  523 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  524 | Best fitness:     0.0161 | Average fitness:    -1.2764
# Generation  525 | Best fitness:     0.0161 | Average fitness:    -1.2411
# Generation  526 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  527 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  528 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  529 | Best fitness:     0.0161 | Average fitness:    -1.2462
# Generation  530 | Best fitness:     0.0161 | Average fitness:    -1.2411
# Generation  531 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  532 | Best fitness:     0.0161 | Average fitness:    -1.2388
# Generation  533 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  534 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  535 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  536 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  537 | Best fitness:     0.0161 | Average fitness:    -1.2621
# Generation  538 | Best fitness:     0.0161 | Average fitness:    -1.2388
# Generation  539 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  540 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  541 | Best fitness:     0.0161 | Average fitness:    -1.2462
# Generation  542 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  543 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  544 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  545 | Best fitness:     0.0161 | Average fitness:    -1.2616
# Generation  546 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  547 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  548 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  549 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  550 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  551 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  552 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  553 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  554 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  555 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  556 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  557 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  558 | Best fitness:     0.0161 | Average fitness:    -1.2457
# Generation  559 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  560 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  561 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  562 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  563 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  564 | Best fitness:     0.0161 | Average fitness:    -1.2411
# Generation  565 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  566 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  567 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  568 | Best fitness:     0.0161 | Average fitness:    -1.2616
# Generation  569 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  570 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  571 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  572 | Best fitness:     0.0161 | Average fitness:    -1.2616
# Generation  573 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  574 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  575 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  576 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  577 | Best fitness:     0.0161 | Average fitness:    -1.2314
# Generation  578 | Best fitness:     0.0161 | Average fitness:    -1.2312
# Generation  579 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  580 | Best fitness:     0.0161 | Average fitness:    -1.2616
# Generation  581 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  582 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  583 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  584 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  585 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  586 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  587 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  588 | Best fitness:     0.0161 | Average fitness:    -1.2406
# Generation  589 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  590 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  591 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  592 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  593 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  594 | Best fitness:     0.0161 | Average fitness:    -1.2616
# Generation  595 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  596 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  597 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  598 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  599 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  600 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  601 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  602 | Best fitness:     0.0161 | Average fitness:    -1.2547
# Generation  603 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  604 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  605 | Best fitness:     0.0161 | Average fitness:    -1.2590
# Generation  606 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  607 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  608 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  609 | Best fitness:     0.0161 | Average fitness:    -1.2312
# Generation  610 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  611 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  612 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  613 | Best fitness:     0.0161 | Average fitness:    -1.2462
# Generation  614 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  615 | Best fitness:     0.0161 | Average fitness:    -1.2411
# Generation  616 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  617 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  618 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  619 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  620 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  621 | Best fitness:     0.0161 | Average fitness:    -1.2411
# Generation  622 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  623 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  624 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  625 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  626 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  627 | Best fitness:     0.0161 | Average fitness:    -1.2462
# Generation  628 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  629 | Best fitness:     0.0161 | Average fitness:    -1.2590
# Generation  630 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  631 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  632 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  633 | Best fitness:     0.0161 | Average fitness:    -1.2462
# Generation  634 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  635 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  636 | Best fitness:     0.0161 | Average fitness:    -1.2664
# Generation  637 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  638 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  639 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  640 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  641 | Best fitness:     0.0161 | Average fitness:    -1.2387
# Generation  642 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  643 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  644 | Best fitness:     0.0161 | Average fitness:    -1.2480
# Generation  645 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  646 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  647 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  648 | Best fitness:     0.0161 | Average fitness:    -1.2312
# Generation  649 | Best fitness:     0.0161 | Average fitness:    -1.2682
# Generation  650 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  651 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  652 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  653 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  654 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  655 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  656 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  657 | Best fitness:     0.0161 | Average fitness:    -1.2485
# ...
# Generation  782 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  783 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  784 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  785 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  786 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  787 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  788 | Best fitness:     0.0161 | Average fitness:    -1.2769
# Generation  789 | Best fitness:     0.0161 | Average fitness:    -1.2690
# Generation  790 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  791 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  792 | Best fitness:     0.0161 | Average fitness:    -1.2695
# Generation  793 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  794 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  795 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  796 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  797 | Best fitness:     0.0161 | Average fitness:    -1.2764
# Generation  798 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  799 | Best fitness:     0.0161 | Average fitness:    -1.2480
# Generation  800 | Best fitness:     0.0161 | Average fitness:    -1.2382
# Generation  801 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  802 | Best fitness:     0.0161 | Average fitness:    -1.2590
# Generation  803 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  804 | Best fitness:     0.0161 | Average fitness:    -1.2621
# Generation  805 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  806 | Best fitness:     0.0161 | Average fitness:    -1.2621
# Generation  807 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  808 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  809 | Best fitness:     0.0161 | Average fitness:    -1.2621
# Generation  810 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  811 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  812 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  813 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  814 | Best fitness:     0.0161 | Average fitness:    -1.2387
# Generation  815 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  816 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  817 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  818 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  819 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  820 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  821 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  822 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  823 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  824 | Best fitness:     0.0161 | Average fitness:    -1.2547
# Generation  825 | Best fitness:     0.0161 | Average fitness:    -1.2480
# Generation  826 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  827 | Best fitness:     0.0161 | Average fitness:    -1.2462
# Generation  828 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  829 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  830 | Best fitness:     0.0161 | Average fitness:    -1.2387
# Generation  831 | Best fitness:     0.0161 | Average fitness:    -1.2517
# Generation  832 | Best fitness:     0.0161 | Average fitness:    -1.2480
# Generation  833 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  834 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  835 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  836 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  837 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  838 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  839 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  840 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  841 | Best fitness:     0.0161 | Average fitness:    -1.2695
# Generation  842 | Best fitness:     0.0161 | Average fitness:    -1.2462
# Generation  843 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  844 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  845 | Best fitness:     0.0161 | Average fitness:    -1.2542
# Generation  846 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  847 | Best fitness:     0.0161 | Average fitness:    -1.2616
# Generation  848 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  849 | Best fitness:     0.0161 | Average fitness:    -1.2388
# Generation  850 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  851 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  852 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  853 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  854 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  855 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  856 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  857 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  858 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  859 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  860 | Best fitness:     0.0161 | Average fitness:    -1.2590
# Generation  861 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  862 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  863 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  864 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  865 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  866 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  867 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  868 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  869 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  870 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  871 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  872 | Best fitness:     0.0161 | Average fitness:    -1.2695
# Generation  873 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  874 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  875 | Best fitness:     0.0161 | Average fitness:    -1.2695
# Generation  876 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  877 | Best fitness:     0.0161 | Average fitness:    -1.2417
# Generation  878 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  879 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  880 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  881 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  882 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  883 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  884 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  885 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  886 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  887 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  888 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  889 | Best fitness:     0.0161 | Average fitness:    -1.2537
# Generation  890 | Best fitness:     0.0161 | Average fitness:    -1.2308
# Generation  891 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  892 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  893 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  894 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  895 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  896 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  897 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  898 | Best fitness:     0.0161 | Average fitness:    -1.2480
# Generation  899 | Best fitness:     0.0161 | Average fitness:    -1.2462
# Generation  900 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  901 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  902 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  903 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  904 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  905 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  906 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  907 | Best fitness:     0.0161 | Average fitness:    -1.2621
# Generation  908 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  909 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  910 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  911 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  912 | Best fitness:     0.0161 | Average fitness:    -1.2387
# Generation  913 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  914 | Best fitness:     0.0161 | Average fitness:    -1.2690
# Generation  915 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  916 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  917 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  918 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  919 | Best fitness:     0.0161 | Average fitness:    -1.2457
# Generation  920 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  921 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  922 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  923 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  924 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  925 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  926 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  927 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  928 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  929 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  930 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  931 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  932 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  933 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  934 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  935 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  936 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  937 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  938 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  939 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  940 | Best fitness:     0.0161 | Average fitness:    -1.2664
# Generation  941 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  942 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  943 | Best fitness:     0.0161 | Average fitness:    -1.2480
# Generation  944 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  945 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  946 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  947 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  948 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  949 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  950 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  951 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  952 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  953 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  954 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  955 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  956 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  957 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  958 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  959 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  960 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  961 | Best fitness:     0.0161 | Average fitness:    -1.2387
# Generation  962 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  963 | Best fitness:     0.0161 | Average fitness:    -1.2312
# Generation  964 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  965 | Best fitness:     0.0161 | Average fitness:    -1.2695
# Generation  966 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  967 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  968 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  969 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  970 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  971 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  972 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  973 | Best fitness:     0.0161 | Average fitness:    -1.2628
# Generation  974 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  975 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  976 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  977 | Best fitness:     0.0161 | Average fitness:    -1.2411
# Generation  978 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  979 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  980 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  981 | Best fitness:     0.0161 | Average fitness:    -1.2462
# Generation  982 | Best fitness:     0.0161 | Average fitness:    -1.2485
# Generation  983 | Best fitness:     0.0161 | Average fitness:    -1.2690
# Generation  984 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  985 | Best fitness:     0.0161 | Average fitness:    -1.2517
# Generation  986 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  987 | Best fitness:     0.0161 | Average fitness:    -1.2387
# Generation  988 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  989 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  990 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  991 | Best fitness:     0.0161 | Average fitness:    -1.2633
# Generation  992 | Best fitness:     0.0161 | Average fitness:    -1.2480
# Generation  993 | Best fitness:     0.0161 | Average fitness:    -1.2708
# Generation  994 | Best fitness:     0.0161 | Average fitness:    -1.2554
# Generation  995 | Best fitness:     0.0161 | Average fitness:    -1.2559
# Generation  996 | Best fitness:     0.0161 | Average fitness:    -1.2702
# Generation  997 | Best fitness:     0.0161 | Average fitness:    -1.2616
# Generation  998 | Best fitness:     0.0161 | Average fitness:    -1.2411
# Generation  999 | Best fitness:     0.0161 | Average fitness:    -1.2411
# Generation 1000 | Best fitness:     0.0161 | Average fitness:    -1.2485

# %%
# print out the best genome
population, fitnesses = evaluate_population(population)

best_genome = population[0]
best_fitness = fitnesses[0]

print(f"Best genome: {best_genome}")
print(f"Best fitness: {best_fitness}")

# Run the simulation with the best genome
genome = [*best_genome[:-2], (best_genome[-2], best_genome[-1])]
genome_dict = dict(zip(genome_mapping, genome))
print(genome_dict)
springlock = Springlock(**genome_dict, angle_units='deg')
springlock.angle_units = 'deg'
springlock.torque_units = 'ozf*in'
print(f'Impact speed is {springlock.max_speed:.2f} {springlock.speed_units}')
print(f'Impact angle is {springlock.impact_angle:.2f} {springlock.angle_units}')
print(f'Release angle is {springlock.release_angle:.2f} {springlock.angle_units}')
print(f'Maximum torque is {springlock.max_torque:.2f} {springlock.torque_units}')
print(f'Maximum torque is at {springlock.max_torque_theta:.2f} {springlock.angle_units}')
print(f'Spring constant is {springlock.spring_constant:.2f} {springlock.spring_constant_units}')
print(f'Stored energy is {springlock.max_potential_energy:.2f} {springlock.energy_units}')
# Out:
# Best genome: [3, 0.4, 114211.96494379424, 0.04875360423932905, 0.056257193587311606, 0.02116991721547297, 0.05710932818817068]
# Best fitness: 0.016050287455557356
# {'weapon_mass': 3, 'weapon_radius': 0.4, 'spring_constant': 114211.96494379424, 'spring_radius': 0.04875360423932905, 'spring_resting_length': 0.056257193587311606, 'spring_mounting_point': (0.02116991721547297, 0.05710932818817068)}
# Impact speed is 10.83 m/s
# Impact angle is -11.82 deg
# Release angle is 109.03 deg
# Maximum torque is 8822.46 ozf*in
# Maximum torque is at 26.04 deg
# Spring constant is 114211.96 N/m
# Stored energy is 173.95 J

# %%
# Create a plot of the torque vs angle from the release angle to the impact angle
angles = np.linspace(springlock.release_angle, springlock.impact_angle, 100)
torques = [springlock.torque(angle) for angle in angles]

plt.plot(angles, torques)
plt.xlabel(f'Angle ({springlock.angle_units})')
plt.ylabel(f'Torque ({springlock.torque_units})')
plt.title('Torque vs Angle')
plt.show()

# %%
# Create a plot of the potential energy vs angle from the release angle to the impact angle
angles = np.linspace(springlock.release_angle, springlock.impact_angle, 100)
energies = [springlock.total_potential_energy(angle) for angle in angles]

plt.plot(angles, energies)
plt.xlabel(f'Angle ({springlock.angle_units})')
plt.ylabel(f'Potential Energy ({springlock.energy_units})')
plt.title('Potential Energy vs Angle')
plt.show()

# %%
# Find the angle at which the spring is at rest
minimize_scalar(springlock.spring_potential_energy, bounds=(min(springlock.release_angle, springlock.impact_angle), max(springlock.release_angle, springlock.impact_angle)), method='bounded')
# Out:
#  message: Solution found.
#  success: True
#   status: 0
#      fun: 2.3153720740527467e-10
#        x: -0.15935417796960347
#      nit: 12
#     nfev: 12

# %%
# Plot the percentage of the population that has a fitness greater than x, from the best to the worst
population, fitnesses = evaluate_population(population)
max_fitness = fitnesses[0]
min_fitness = fitnesses[-1]

fitness_measurements = np.linspace(min_fitness, max_fitness, 100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       3 max_fitness = fitnesses[0]
#       4 min_fitness = fitnesses[-1]
# ----> 6 fitness_meas
#
# NameError: name 'fitness_meas' is not defined
